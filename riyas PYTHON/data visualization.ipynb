# %%
import matplotlib.pyplot

# %%
pip install matplotlib
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import matplotlib.pyplot as plt

# %%
toyato=['glanza','innova','crysta','fortuner','landcruicer']
percentage=[21,25,15,10,5]

# %%
plt.bar(toyato,percentage)
# Out:
# <BarContainer object of 5 artists>

# %%
plt.scatter(toyato,percentage)

# %%
plt.plot(toyato,percentage,linestyle='dashdot')

# %%
plt.pie(percentage,labels=toyato)
# Out:
# ([<matplotlib.patches.Wedge at 0x21fdb60ace0>,
# ...
#  [Text(0.710929190601096, 0.8393924504969477, 'glanza'),
#   Text(-1.0247501653301052, 0.3998588484151907, 'innova'),
#   Text(-0.31386991680857756, -1.054270209824112, 'crysta'),
#   Text(0.7450097048603814, -0.809296323767659, 'fortuner'),
#   Text(1.0765885281915364, -0.22573688437289488, 'landcruicer')])

# %% [markdown]
# # sine wave

# %%
import numpy as np

# %%
time=np.arange(0,10,0.05)

# %%
time
# Out:
# array([0.  , 0.05, 0.1 , 0.15, 0.2 , 0.25, 0.3 , 0.35, 0.4 , 0.45, 0.5 ,
#        0.55, 0.6 , 0.65, 0.7 , 0.75, 0.8 , 0.85, 0.9 , 0.95, 1.  , 1.05,
#        1.1 , 1.15, 1.2 , 1.25, 1.3 , 1.35, 1.4 , 1.45, 1.5 , 1.55, 1.6 ,
#        1.65, 1.7 , 1.75, 1.8 , 1.85, 1.9 , 1.95, 2.  , 2.05, 2.1 , 2.15,
#        2.2 , 2.25, 2.3 , 2.35, 2.4 , 2.45, 2.5 , 2.55, 2.6 , 2.65, 2.7 ,
#        2.75, 2.8 , 2.85, 2.9 , 2.95, 3.  , 3.05, 3.1 , 3.15, 3.2 , 3.25,
#        3.3 , 3.35, 3.4 , 3.45, 3.5 , 3.55, 3.6 , 3.65, 3.7 , 3.75, 3.8 ,
#        3.85, 3.9 , 3.95, 4.  , 4.05, 4.1 , 4.15, 4.2 , 4.25, 4.3 , 4.35,
#        4.4 , 4.45, 4.5 , 4.55, 4.6 , 4.65, 4.7 , 4.75, 4.8 , 4.85, 4.9 ,
#        4.95, 5.  , 5.05, 5.1 , 5.15, 5.2 , 5.25, 5.3 , 5.35, 5.4 , 5.45,
#        5.5 , 5.55, 5.6 , 5.65, 5.7 , 5.75, 5.8 , 5.85, 5.9 , 5.95, 6.  ,
#        6.05, 6.1 , 6.15, 6.2 , 6.25, 6.3 , 6.35, 6.4 , 6.45, 6.5 , 6.55,
#        6.6 , 6.65, 6.7 , 6.75, 6.8 , 6.85, 6.9 , 6.95, 7.  , 7.05, 7.1 ,
# ...

# %%
amplitude=np.sin(time)

# %%
amplitude
# Out:
# array([ 0.        ,  0.04997917,  0.09983342,  0.14943813,  0.19866933,
#         0.24740396,  0.29552021,  0.34289781,  0.38941834,  0.43496553,
#         0.47942554,  0.52268723,  0.56464247,  0.60518641,  0.64421769,
#         0.68163876,  0.71735609,  0.75128041,  0.78332691,  0.8134155 ,
#         0.84147098,  0.86742323,  0.89120736,  0.91276394,  0.93203909,
#         0.94898462,  0.96355819,  0.97572336,  0.98544973,  0.99271299,
#         0.99749499,  0.99978376,  0.9995736 ,  0.99686503,  0.99166481,
#         0.98398595,  0.97384763,  0.9612752 ,  0.94630009,  0.92895972,
#         0.90929743,  0.88736237,  0.86320937,  0.83689879,  0.8084964 ,
#         0.7780732 ,  0.74570521,  0.71147335,  0.67546318,  0.6377647 ,
#         0.59847214,  0.55768372,  0.51550137,  0.47203054,  0.42737988,
#         0.38166099,  0.33498815,  0.28747801,  0.23924933,  0.19042265,
#         0.14112001,  0.09146464,  0.04158066, -0.00840725, -0.05837414,
# ...

# %%
plt.plot(time,amplitude)

# %%
pip install seaborn
# Out:
# ...
#      -------------------------------------- 288.2/288.2 kB 4.4 MB/s eta 0:00:00
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import seaborn as sns

# %%
sns.set(style='darkgrid')

# %%
import numpy as np

# %%
random=np.random.randn(100)

# %%
random
# Out:
# array([-1.60900668e+00,  7.13480141e-01, -1.69405870e+00,  1.34650386e+00,
#         4.80045086e-01,  2.32430431e+00,  1.98817027e+00, -5.51750901e-01,
#        -5.88352730e-01,  1.73238645e+00, -1.82220909e+00,  1.47795692e+00,
#        -5.55419238e-02, -1.15686693e+00,  1.73967201e-03, -1.21827063e+00,
#        -2.98263348e-01,  1.04418311e+00, -1.07056700e+00, -4.29974766e-01,
#         1.47361792e-01,  1.02020285e-01, -1.23128599e+00, -1.48419746e+00,
#        -8.29937797e-02,  1.52228298e+00,  2.05825275e+00,  2.47414219e-01,
#        -9.40149063e-02,  6.77127940e-03,  1.64383405e+00,  1.28865973e+00,
#         1.12568994e-01, -2.47867423e-01, -3.50037121e-01,  6.43702434e-01,
#         4.92944467e-02, -8.00177382e-01, -2.00367378e-01, -6.29141150e-01,
#        -1.11940871e+00,  1.87188422e+00, -1.67036994e+00,  3.90949074e-01,
#         6.80530873e-01,  7.29358616e-01,  9.58147956e-02, -1.65519448e+00,
# ...

# %%
sns.distplot(random)
# Out:
# C:\Users\ADMIN\AppData\Local\Temp\ipykernel_7816\1899859526.py:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random)
# <AxesSubplot: ylabel='Density'>

# %%
sns.get_dataset_names()
# Out:
# ['anagrams',
#  'anscombe',
#  'attention',
#  'brain_networks',
#  'car_crashes',
#  'diamonds',
#  'dots',
#  'dowjones',
#  'exercise',
#  'flights',
#  'fmri',
#  'geyser',
#  'glue',
#  'healthexp',
#  'iris',
#  'mpg',
#  'penguins',
#  'planets',
#  'seaice',
#  'taxis',
#  'tips',
#  'titanic']

# %%
tip=sns.load_dataset('diamonds')

# %%
tip
# Out:
#        carat        cut color clarity  depth  table  price     x     y     z
# 0       0.23      Ideal     E     SI2   61.5   55.0    326  3.95  3.98  2.43
# 1       0.21    Premium     E     SI1   59.8   61.0    326  3.89  3.84  2.31
# 2       0.23       Good     E     VS1   56.9   65.0    327  4.05  4.07  2.31
# 3       0.29    Premium     I     VS2   62.4   58.0    334  4.20  4.23  2.63
# 4       0.31       Good     J     SI2   63.3   58.0    335  4.34  4.35  2.75
# ...      ...        ...   ...     ...    ...    ...    ...   ...   ...   ...
# 53935   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75  5.76  3.50
# 53936   0.72       Good     D     SI1   63.1   55.0   2757  5.69  5.75  3.61
# 53937   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66  5.68  3.56
# 53938   0.86    Premium     H     SI2   61.0   58.0   2757  6.15  6.12  3.74
# 53939   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83  5.87  3.64
#
# [53940 rows x 10 columns]

# %%
 sns.relplot(x='carat',y='price',data=tip, col="clarity",hue="table",style="color",kind="line")

# %%
pip install sklearn
# Out:
# ...
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# ...
#   Created wheel for sklearn: filename=sklearn-0.0.post1-py3-none-any.whl size=2936 sha256=2d205299c33a64bf2b5bf0ef0771dd80a422f91ea3dd53344a53a26ed7b1dec4
#   Stored in directory: c:\users\admin\appdata\local\pip\cache\wheels\c5\88\35\cc8a1e198b27a1d3d9d3f9b30090b9d5531778847835472ec4
# Successfully built sklearn
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import sklearn as sk
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In [1], line 1
# ----> 1 import sklearn as sk
#
# ModuleNotFoundError: No module named 'sklearn'

# %%
from sklearn.preo
